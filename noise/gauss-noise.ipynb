# %%
import numpy as np
from matplotlib import pyplot as plt 
import cv2

# %% [markdown]
# ## Original Picture

# %%
path = "./../images/siteng1.jpg"
img = cv2.imread(path,cv2.IMREAD_GRAYSCALE)
plt.imshow(img,cmap="gray")

# %%
img = cv2.imread(path , cv2.IMREAD_GRAYSCALE)

# %%
h,w = img.shape
noise = 8*np.random.randn(h,w)
noise
# Out:
# array([[ -5.76515855,   2.03848131,   0.25973514, ...,   8.9938382 ,
#           3.25887946, -10.82053507],
#        [ -9.76955736,  -3.88456404,  -8.33327756, ...,   8.60962082,
#           0.86498986, -10.28422407],
#        [ 10.58140765, -17.45485766,  -7.799762  , ..., -17.048301  ,
#           3.58161413,  -9.4323455 ],
#        ...,
#        [  9.951966  ,  -7.47991487,   5.92696212, ..., -13.67154931,
#          10.9875766 ,  -0.51394697],
#        [ -4.9810862 ,  -6.40193404,  14.754609  , ..., -10.48920903,
#           5.71292602,   0.23963368],
#        [  4.79095958,   8.37093928,   2.54457641, ...,   2.08222176,
#           9.25624541,   1.65154897]])

# %%
g = img + noise
g = g.astype(np.uint8)
