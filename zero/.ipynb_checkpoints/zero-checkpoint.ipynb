# %%
import numpy as np 
import cv2 
from hello import *
from matplotlib import pyplot as plt

# %% [markdown]
# 原图

# %%
im_color = cv2.imread("./../images/siteng1.jpg")
im_color = cv2.cvtColor(im_color,cv2.COLOR_BGR2RGB)
plt.imshow(im_color)
plt.show()

# %% [raw]
# 灰度图

# %%
im = cv2.imread("./../images/siteng1.jpg",cv2.IMREAD_GRAYSCALE)
im_copy = cv2.cvtColor(im.copy(),cv2.COLOR_BGR2RGB)
plt.imshow(im_copy)
plt.show()

# %%
np.shape(im)
# Out:
# (1080, 1920)

# %%
#samping rate
sr = 100
ts = 1.0 /sr
t= np.arange(0,1,ts)

freq = 1.
x = 3 * np.sin(2 * np.pi*freq*t)
freq = 4 
x += np.sin(2*np.pi*freq*t)

freq = 7 
x+=0.5*np.sin(2*np.pi*freq*t)

plt.figure(figsize=(8,6))
plt.plot(t,x,'r')
plt.ylabel("Amplitude")
plt.show()
x
# Out:
# array([ 0.00000000e+00,  6.49951092e-01,  1.24301000e+00,  1.73098263e+00,
#         2.08154121e+00,  2.28261600e+00,  2.34327722e+00,  2.29102039e+00,
#         2.16602580e+00,  2.01350931e+00,  1.87561275e+00,  1.78433917e+00,
#         1.75681059e+00,  1.79365925e+00,  1.88074856e+00,  1.99377423e+00,
#         2.10474409e+00,  2.18898123e+00,  2.23120727e+00,  2.22945607e+00,
#         2.19600566e+00,  2.15511222e+00,  2.13796970e+00,  2.17587843e+00,
#         2.29297677e+00,  2.50000000e+00,  2.79035655e+00,  3.13938578e+00,
#         3.50706391e+00,  3.84376807e+00,  4.09811869e+00,  4.22550953e+00,
#         4.19578177e+00,  3.99863534e+00,  3.64577057e+00,  3.16934473e+00,
#         2.61699766e+00,  2.04432572e+00,  1.50614412e+00,  1.04809007e+00,
#         7.00042246e-01,  4.72482828e-01,  3.56371693e-01,  3.26445884e-01,
#         3.47223767e-01,  3.80502964e-01,  3.92885361e-01,  3.61888418e-01,
# ...

# %%
from dft import *

# %%
X = dft(x)

N = len(X)
n = np.arange(N)
T = N / sr
freq = n / T

plt.figure(figsize = (8,6))
plt.stem(freq,abs(X) , 'b' , markerfmt= " " , basefmt='-b')
plt.xlabel("Freq (Hz)")
plt.ylabel("DFT Amplitude |X(freq)|")
plt.show()

# %%
x= idft(X)
plt.figure(figsize=(8,6))
plt.plot(t,x,'r')
plt.ylabel("Amplitude")
plt.show()
x
# Out:
# /home/zhx/.local/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# array([ 4.08939388e-14-1.14199724e-14j,  6.49951092e-01-3.81106298e-14j,
#         1.24301000e+00+4.08340827e-14j,  1.73098263e+00-1.23411371e-14j,
#         2.08154121e+00+1.43293617e-14j,  2.28261600e+00+2.35932067e-14j,
#         2.34327722e+00-3.09907934e-14j,  2.29102039e+00-7.66039872e-15j,
#         2.16602580e+00+1.37032699e-14j,  2.01350931e+00-2.88621747e-14j,
#         1.87561275e+00-3.11500085e-14j,  1.78433917e+00-2.78060795e-14j,
#         1.75681059e+00-8.14300563e-15j,  1.79365925e+00-9.10374417e-16j,
#         1.88074856e+00-5.41601545e-14j,  1.99377423e+00-4.56101840e-14j,
#         2.10474409e+00-2.61878054e-14j,  2.18898123e+00-1.33814869e-14j,
#         2.23120727e+00-6.28300737e-15j,  2.22945607e+00-2.84263108e-14j,
# ...

# %%
dft2im = dft2(im)
print(dft2im)
# Out:
# [[ 35  27  26 ...  23  26  36]
#  [ 35  25  27 ...  25  27  36]
#  [ 37  28  25 ...  27  25  38]
#  ...
#  [ 31  23  21 ... 183 179 174]
#  [ 31  22  20 ... 185 180 175]
#  [ 30  22  22 ... 183 176 174]]

# %%
plt.imshow(dft2im,'gray')

# %%
f = np.fft.fft2(im)
pf_f = np.angle(f)

# %%
plt.imshow(pf_f,"gray")

# %%
im = np.fft.ifft2(pf_f)
plt.imshow(pf_f,"gray")
